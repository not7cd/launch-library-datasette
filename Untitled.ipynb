# %%
import requests
from copy import copy
from glom import glom, flatten
from dateutil.parser import parse as parse_dt
from sqlite_utils import Database

from pprint import pprint

# %%
BASE_URL = "https://launchlibrary.net/1.4.1/"

# %%
pads_raw = requests.get(BASE_URL + "pad/?limit=1000&mode=verbose").json()
locations_raw = requests.get(BASE_URL + "location/?limit=1000&mode=verbose").json()

# %%
agencies_raw = requests.get(BASE_URL + "agency?limit=1000&mode=verbose").json()
agency_types_raw = requests.get(BASE_URL + "agencytype?limit=1000&mode=verbose").json()

# %%
rockets_raw = requests.get(BASE_URL + "rocket?limit=1000&mode=verbose").json()
families_raw = requests.get(BASE_URL + "rocketfamily?limit=1000&mode=verbose").json()

# %%
launches_raw = requests.get(BASE_URL + "launch?limit=3000&mode=verbose").json()

# %%
missions_raw = requests.get(BASE_URL + "mission?limit=2000&mode=verbose").json()
missions_raw
# Out:
# {'missions': [{'id': 5,
#    'name': 'Nuclear Spectroscopic Telescope Array (NuSTAR)',
#    'description': 'Designed to image high-energy X-ray radiation, the Nuclear Spectroscopic Telescope Array (NuSTAR) is tasked with surveying regions surrounding the center of own Milky Way Galaxy and performing deep observations of the extragalactic sky, studying black holes and supernovas.',
#    'agencies': [{'id': 44,
#      'name': 'National Aeronautics and Space Administration',
#      'abbrev': 'NASA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#      'infoURLs': ['http://www.nasa.gov',
#       'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#       'https://twitter.com/nasa',
#       'https://www.facebook.com/nasa']}],
#    'type': 3,
#    'typeName': 'Astrophysics',
#    'launch': {'id': 628,
#     'name': 'Pegasus XL | Nuclear Spectroscopic Telescope Array (NuSTAR)',
#     'windowstart': 'June 13, 2012 16:00:37 UTC',
#     'windowend': 'June 13, 2012 16:00:37 UTC',
#     'net': 'June 13, 2012 16:00:37 UTC'},
#    'infoURL': 'http://www.nasa.gov/mission_pages/nustar/overview/index.html',
#    'wikiURL': 'https://en.wikipedia.org/wiki/NuSTAR',
#    'events': None,
#    'infoURLs': ['http://www.nasa.gov/mission_pages/nustar/overview/index.html'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 3,
#    'name': 'WGS-4 (USA-233)',
#    'description': 'The United Launch Alliance Delta 4 rocket launched the fourth Wideband Global SATCOM spacecraft, formerly known as the Wideband Gapfiller Satellite. Built by Boeing, this geostationary communications spacecraft serves U.S. military forces.',
#    'agencies': [{'id': 124,
#      'name': 'United Launch Alliance',
#      'abbrev': 'ULA',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/United_Launch_Alliance',
#      'infoURLs': ['http://www.ulalaunch.com/',
#       'https://www.youtube.com/channel/UCnrGPRKAg1PgvuSHrRIl3jg',
#       'https://twitter.com/ulalaunch',
#       'https://www.facebook.com/ulalaunch',
#       'https://www.instagram.com/ulalaunch/']},
#     {'id': 165,
#      'name': 'US Army',
#      'abbrev': 'USA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/US_Army',
#      'infoURLs': ['http://www.army.mil',
#       'https://www.facebook.com/USarmy',
#       'https://twitter.com/USArmy',
#       'https://www.youtube.com/USarmy',
#       'https://www.flickr.com/photos/soldiersmediacenter',
#       'https://www.instagram.com/usarmy']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 598,
#     'name': 'Delta IV M+(5,4) | WGS-4 (USA-233)',
#     'windowstart': 'January 20, 2012 00:38:00 UTC',
#     'windowend': 'January 20, 2012 00:38:00 UTC',
#     'net': 'January 20, 2012 00:38:00 UTC'},
#    'infoURL': 'http://www.af.mil/AboutUs/FactSheets/Display/tabid/224/Article/104512/wideband-global-satcom-satellite.aspx',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Wideband_Global_SATCOM',
#    'events': None,
#    'infoURLs': ['http://www.af.mil/AboutUs/FactSheets/Display/tabid/224/Article/104512/wideband-global-satcom-satellite.aspx'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 4,
#    'name': 'SES-4',
#    'description': 'An International Launch Services Proton rocket with a Breeze M upper stage will deploy the SES 4 satellite to provide telecommunications services over the Americas, Africa, Europe and the Middle East. ',
#    'agencies': [{'id': 203,
#      'name': 'SES',
#      'abbrev': 'SES',
#      'countryCode': 'LUX',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'https://en.wikipedia.org/wiki/SES_S.A.',
#      'infoURLs': []}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 602,
#     'name': 'Proton-M Briz-M | SES-4',
#     'windowstart': 'February 14, 2012 19:36:37 UTC',
#     'windowend': 'February 14, 2012 19:36:37 UTC',
#     'net': 'February 14, 2012 19:36:37 UTC'},
#    'infoURL': 'http://www.ses.com/4628467/ses-4',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': ['http://www.ses.com/4628467/ses-4'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 6,
#    'name': 'Dragon C2',
#    'description': 'SpaceX COTS Demo Flight 2',
#    'agencies': [{'id': 44,
#      'name': 'National Aeronautics and Space Administration',
#      'abbrev': 'NASA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#      'infoURLs': ['http://www.nasa.gov',
#       'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#       'https://twitter.com/nasa',
#       'https://www.facebook.com/nasa']}],
#    'type': 0,
#    'launch': None,
#    'infoURL': '',
#    'wikiURL': 'http://wiki.spacevidcast.com/en/List_of_Upcoming_Launches',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 7,
#    'name': 'SpX CRS-1',
#    'description': 'This was the third flight for the uncrewed Dragon cargo spacecaft and the first SpaceX mission under their Commercial Resupply Services contract with NASA. Dragon delivered various cargo to the staion, and returned after being berthed to the station for 17 days. The spacecraft landed in the Pacific Ocean and was recovered by SpaceX.',
#    'agencies': [{'id': 44,
#      'name': 'National Aeronautics and Space Administration',
#      'abbrev': 'NASA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#      'infoURLs': ['http://www.nasa.gov',
#       'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#       'https://twitter.com/nasa',
#       'https://www.facebook.com/nasa']}],
#    'type': 11,
#    'typeName': 'Resupply',
#    'launch': {'id': 651,
#     'name': 'Falcon 9 v1.0 | SpX CRS-1',
#     'windowstart': 'October 8, 2012 00:35:07 UTC',
#     'windowend': 'October 8, 2012 00:35:07 UTC',
#     'net': 'October 8, 2012 00:35:07 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/SpaceX_CRS-1',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 12,
#    'name': 'TDRS-K',
#    'description': 'TDRS-11, known before launch as TDRS-K, is an American communications satellite which is operated by NASA as part of the Tracking and Data Relay Satellite System, which provides a multitude of communications services to a wide variety of missions.',
#    'agencies': [{'id': 44,
#      'name': 'National Aeronautics and Space Administration',
#      'abbrev': 'NASA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#      'infoURLs': ['http://www.nasa.gov',
#       'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#       'https://twitter.com/nasa',
#       'https://www.facebook.com/nasa']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 517,
#     'name': 'Atlas V 401 | TDRS-K',
#     'windowstart': 'January 31, 2013 01:48:00 UTC',
#     'windowend': 'January 31, 2013 01:48:00 UTC',
#     'net': 'January 31, 2013 01:48:00 UTC'},
#    'infoURL': 'http://tdrs.gsfc.nasa.gov/tdrs/136.html',
#    'wikiURL': 'https://en.wikipedia.org/wiki/TDRS-11',
#    'events': None,
#    'infoURLs': ['http://tdrs.gsfc.nasa.gov/tdrs/136.html'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 14,
#    'name': '6 x Globalstar-2',
#    'description': 'The Globalstar second-generation constellation consists of 24 Low Earth Orbiting satellites for satellite phone and data communications.',
#    'agencies': [{'id': 204,
#      'name': 'Globalstar',
#      'abbrev': 'GSAT',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': '',
#      'wikiURL': 'https://en.wikipedia.org/wiki/Globalstar',
#      'infoURLs': []}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 520,
#     'name': 'Soyuz-2.1a/Fregat | 6 x Globalstar-2',
#     'windowstart': 'February 6, 2013 16:04:24 UTC',
#     'windowend': 'February 6, 2013 16:04:24 UTC',
#     'net': 'February 6, 2013 16:04:24 UTC'},
#    'infoURL': 'http://www.globalstar.com/en/index.php?cid=8300',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Globalstar#Second-generation_satellites',
#    'events': None,
#    'infoURLs': ['http://www.globalstar.com/en/index.php?cid=8300'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 16,
#    'name': 'SARAL',
#    'description': 'SARAL or Satellite with ARgos and ALtiKa is a cooperative altimetry technology mission of Indian Space Research Organisation (ISRO) and CNES (Space Agency of France). SARAL is tasked to perform altimetric measurements designed to study ocean circulation and sea surface elevation.',
#    'agencies': [{'id': 31,
#      'name': 'Indian Space Research Organization',
#      'abbrev': 'ISRO',
#      'countryCode': 'IND',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Indian_Space_Research_Organization',
#      'infoURLs': ['https://www.isro.gov.in/',
#       'https://twitter.com/ISRO',
#       'https://www.youtube.com/channel/UCw5hEVOTfz_AfzsNFWyNlNg',
#       'https://www.facebook.com/ISRO']},
#     {'id': 46,
#      'name': 'National Center of Space Research',
#      'abbrev': 'CNES',
#      'countryCode': 'FRA',
#      'type': 1,
#      'infoURL': 'http://www.cnes.fr/',
#      'wikiURL': 'http://en.wikipedia.org/wiki/CNES',
#      'infoURLs': ['http://www.cnes.fr/']}],
#    'type': 2,
#    'typeName': 'Planetary Science',
#    'launch': {'id': 524,
#     'name': 'PSLV-CA | SARAL',
#     'windowstart': 'February 25, 2013 12:31:00 UTC',
#     'windowend': 'February 25, 2013 12:31:00 UTC',
#     'net': 'February 25, 2013 12:31:00 UTC'},
#    'infoURL': 'http://www.isro.gov.in/Spacecraft/saral',
#    'wikiURL': 'https://en.wikipedia.org/wiki/SARAL',
#    'events': None,
#    'infoURLs': ['http://www.isro.gov.in/Spacecraft/saral',
#     'https://altika-saral.cnes.fr/en/SARAL/GP_satellite.htm'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 19,
#    'name': 'Orbital Sciences Antares Rocket',
#    'description': 'Simulated Cynus Spacecraft Launch',
#    'agencies': None,
#    'type': 0,
#    'launch': None,
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 20,
#    'name': 'Landsat Data Continuity Mission',
#    'description': 'US Geological Survey',
#    'agencies': None,
#    'type': 0,
#    'launch': None,
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 21,
#    'name': 'Eutelsat 115 West B & ABS-3A',
#    'description': 'These are both geostationary communication satellites, with Eutelsat 155 West B providing coverage in the Americas, and ABS-3A providing coverage in the Americas, the Middle East, and Africa.',
#    'agencies': [{'id': 121,
#      'name': 'SpaceX',
#      'abbrev': 'SpX',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/SpaceX',
#      'infoURLs': ['http://www.spacex.com/',
#       'https://twitter.com/SpaceX',
#       'https://www.youtube.com/channel/UCtI0Hodo5o5dUb67FeUjDeA']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 208,
#     'name': 'Falcon 9 v1.1 | Eutelsat 115 West B & ABS-3A',
#     'windowstart': 'March 2, 2015 03:50:00 UTC',
#     'windowend': 'March 2, 2015 03:50:00 UTC',
#     'net': 'March 2, 2015 03:50:00 UTC'},
#    'infoURL': 'http://www.eutelsat.com/en/satellites/EUTELSAT-115WB.html',
#    'wikiURL': 'https://en.wikipedia.org/wiki/ABS-3A',
#    'events': None,
#    'infoURLs': ['http://www.eutelsat.com/en/satellites/EUTELSAT-115WB.html'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 22,
#    'name': 'Anik-G1',
#    'description': 'Anik-G1 is a communications satellite, operated by Telesat Canada to provide direct-to-home TV services in Canada.',
#    'agencies': [],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 529,
#     'name': 'Proton-M Briz-M | Anik-G1',
#     'windowstart': 'April 15, 2013 18:36:00 UTC',
#     'windowend': 'April 15, 2013 18:36:00 UTC',
#     'net': 'April 15, 2013 18:36:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Anik_(satellite)#Anik_G1',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 24,
#    'name': 'Resurs-P No.1',
#    'description': 'Resurs-P No.1 is a Russian commercial earth observation satellite capable of acquiring high-resolution imagery (resolution up to 1.0 m).',
#    'agencies': [{'id': 63,
#      'name': 'Russian Federal Space Agency (ROSCOSMOS)',
#      'abbrev': 'RFSA',
#      'countryCode': 'RUS',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Russian_Federal_Space_Agency',
#      'infoURLs': ['http://en.roscosmos.ru/',
#       'https://www.youtube.com/channel/UCOcpUgXosMCIlOsreUfNFiA',
#       'https://twitter.com/Roscosmos',
#       'https://www.facebook.com/Roscosmos']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 545,
#     'name': 'Soyuz 2.1b | Resurs-P No.1',
#     'windowstart': 'June 25, 2013 17:28:48 UTC',
#     'windowend': 'June 25, 2013 17:28:48 UTC',
#     'net': 'June 25, 2013 17:28:48 UTC'},
#    'infoURL': 'http://www.russianspaceweb.com/resurs_p.html',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Resurs-P_No.1',
#    'events': None,
#    'infoURLs': ['http://www.russianspaceweb.com/resurs_p.html'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 27,
#    'name': 'CBERS-3',
#    'description': 'This remote sensing satellite was intended for China-Brazil program on Environment, Agriculture, and Urban Planning.',
#    'agencies': [{'id': 17,
#      'name': 'China National Space Administration',
#      'abbrev': 'CNSA',
#      'countryCode': 'CHN',
#      'type': 1,
#      'infoURL': 'http://www.cnsa.gov.cn/',
#      'wikiURL': 'http://en.wikipedia.org/wiki/China_National_Space_Administration',
#      'infoURLs': ['http://www.cnsa.gov.cn/']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 590,
#     'name': 'Long March 4B | CBERS-3',
#     'windowstart': 'December 9, 2013 03:26:00 UTC',
#     'windowend': 'December 9, 2013 03:26:00 UTC',
#     'net': 'December 9, 2013 03:26:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/CBERS-3',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 28,
#    'name': 'SpX CRS-2',
#    'description': "This was the fourth flight for SpaceX's uncrewed Dragon cargo spacecraft, the fifth and final flight for the company's two-stage Falcon 9 v1.0 launch vehicle, and the second SpaceX operational mission contracted to NASA under a Commercial Resupply Services contract. The launch occurred on March 1, 2013. A minor technical issue on the Dragon spacecraft involving the RCS thruster pods occurred upon reaching orbit, but it was recoverable. The vehicle was released, splashed down, and recovered by SpaceX.",
#    'agencies': [{'id': 44,
#      'name': 'National Aeronautics and Space Administration',
#      'abbrev': 'NASA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#      'infoURLs': ['http://www.nasa.gov',
#       'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#       'https://twitter.com/nasa',
#       'https://www.facebook.com/nasa']}],
#    'type': 11,
#    'typeName': 'Resupply',
#    'launch': {'id': 525,
#     'name': 'Falcon 9 v1.0 | SpX CRS-2',
#     'windowstart': 'March 1, 2013 15:10:13 UTC',
#     'windowend': 'March 1, 2013 15:10:13 UTC',
#     'net': 'March 1, 2013 15:10:13 UTC'},
#    'infoURL': 'http://www.nasa.gov/multimedia/imagegallery/image_feature_2461.html',
#    'wikiURL': 'https://en.wikipedia.org/wiki/SpaceX_CRS-2',
#    'events': None,
#    'infoURLs': ['http://www.nasa.gov/multimedia/imagegallery/image_feature_2461.html'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 29,
#    'name': 'SBIRS GEO Flight 2 (USA-241) (SBIRS GEO-2)',
#    'description': 'This geostationary satellite is tasked with providing capabilities for early missile warning and missile defense.',
#    'agencies': [{'id': 124,
#      'name': 'United Launch Alliance',
#      'abbrev': 'ULA',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/United_Launch_Alliance',
#      'infoURLs': ['http://www.ulalaunch.com/',
#       'https://www.youtube.com/channel/UCnrGPRKAg1PgvuSHrRIl3jg',
#       'https://twitter.com/ulalaunch',
#       'https://www.facebook.com/ulalaunch',
#       'https://www.instagram.com/ulalaunch/']}],
#    'type': 7,
#    'typeName': 'Government/Top Secret',
#    'launch': {'id': 526,
#     'name': 'Atlas V 401 | SBIRS GEO Flight 2 (USA-241) (SBIRS GEO-2)',
#     'windowstart': 'March 19, 2013 21:21:00 UTC',
#     'windowend': 'March 19, 2013 21:21:00 UTC',
#     'net': 'March 19, 2013 21:21:00 UTC'},
#    'infoURL': 'http://www.lockheedmartin.com/us/products/sbirs.html',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Space-Based_Infrared_System',
#    'events': None,
#    'infoURLs': ['http://www.lockheedmartin.com/us/products/sbirs.html'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 408,
#    'name': 'Apollo-Soyuz Test Project',
#    'description': "The Apollo-Soyuz Test Project was the first joint US-Soviet space flight and the last crewed US space mission until the Space Shuttle program.\nThe US side of mission began on July 15, 1975, 19:50:00 UTC, launching Commander Thomas P. Stafford, Command Module Pilot Vance D. Brand and Docking Module Pilot Donald K. Slayton into orbit. Two days later, they docked with the Soyuz 19 spacecraft. American and Soviet crews visited each other's spacecrafts, performed docking and redocking maneuvers, conducted joint scientific experiments, exchanged flags and gifts. Crews spent more than 44 hours together, and after final parting of the ships on July 19, Apollo crew spent nine more days in orbit, conducting Earth observation experiments.\nThe Apollo crew returned to Earth on July 24, 1975, 21:18:0 UTC with a splashdown in the Pacific Ocean.",
#    'agencies': [{'id': 44,
#      'name': 'National Aeronautics and Space Administration',
#      'abbrev': 'NASA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#      'infoURLs': ['http://www.nasa.gov',
#       'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#       'https://twitter.com/nasa',
#       'https://www.facebook.com/nasa']},
#     {'id': 66,
#      'name': 'Soviet Space Program',
#      'abbrev': 'CCCP',
#      'countryCode': 'RUS',
#      'type': 1,
#      'infoURL': '',
#      'wikiURL': 'http://en.wikipedia.org/wiki/Soviet_space_program',
#      'infoURLs': []}],
#    'type': 5,
#    'typeName': 'Human Exploration',
#    'launch': {'id': 972,
#     'name': 'Saturn IB | Apollo-Soyuz Test Project',
#     'windowstart': 'July 15, 1975 19:50:00 UTC',
#     'windowend': 'July 15, 1975 19:50:00 UTC',
#     'net': 'July 15, 1975 19:50:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Apollo%E2%80%93Soyuz_Test_Project',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2020-05-06 18:02:16',
#    'payloads': []},
#   {'id': 212,
#    'name': 'Vostok 1',
#    'description': 'The first crewed space launch & the first orbital launch. It carried the Soviet cosmonaut Yuri Gagarin who completed 1 orbit before safely re-entering the atmosphere, he ejected from his capsule at an altitude of 7 km in order to parachute safely to the ground. The mission lasted 108 minutes.',
#    'agencies': [{'id': 6,
#      'name': 'Asia-Pacific Regional Space Agency Forum',
#      'abbrev': 'APRSAF',
#      'countryCode': 'AUS,BGD,BRN,BTN,CAN,KHM,CHN,FRA,DEU,IND,IDN,JPN,LAO,MYS,MNG,MMR,NPL,NZL,PAK,PHL,RUS,SGP,KOR,LKA,THA,USA,VNM',
#      'type': 2,
#      'infoURL': 'http://www.aprsaf.org/',
#      'wikiURL': '',
#      'infoURLs': ['http://www.aprsaf.org/']},
#     {'id': 66,
#      'name': 'Soviet Space Program',
#      'abbrev': 'CCCP',
#      'countryCode': 'RUS',
#      'type': 1,
#      'infoURL': '',
#      'wikiURL': 'http://en.wikipedia.org/wiki/Soviet_space_program',
#      'infoURLs': []}],
#    'type': 5,
#    'typeName': 'Human Exploration',
#    'launch': {'id': 1028,
#     'name': 'Vostok-K | Vostok 1',
#     'windowstart': 'April 12, 1961 06:07:00 UTC',
#     'windowend': 'April 12, 1961 06:07:00 UTC',
#     'net': 'April 12, 1961 06:07:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Vostok_1',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 32,
#    'name': 'GSAT-14',
#    'description': 'GSAT-14 is an Indian communications satellite, which replaced the GSAT-3 satellite. With a mass of 1982 kg, GSAT-14 is expected to operate in orbit for 12 years.',
#    'agencies': [{'id': 204,
#      'name': 'Globalstar',
#      'abbrev': 'GSAT',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': '',
#      'wikiURL': 'https://en.wikipedia.org/wiki/Globalstar',
#      'infoURLs': []}],
#    'type': 0,
#    'launch': {'id': 38,
#     'name': 'GSLV Mk II | GSAT-14',
#     'windowstart': 'January 5, 2014 10:48:00 UTC',
#     'windowend': 'January 5, 2014 10:48:00 UTC',
#     'net': 'January 5, 2014 10:48:00 UTC'},
#    'infoURL': 'http://www.isro.gov.in/Spacecraft/gsat-14-0',
#    'wikiURL': 'https://en.wikipedia.org/wiki/GSAT-14',
#    'events': None,
#    'infoURLs': ['http://www.isro.gov.in/Spacecraft/gsat-14-0'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 34,
#    'name': 'Swarm A, B, C',
#    'description': "European Space Agency's mission Swarm consists of 3 satellites tasked with studying Earth's magnetic field.",
#    'agencies': [{'id': 117,
#      'name': 'Eurockot Launch Services',
#      'abbrev': 'ELS',
#      'countryCode': 'FRA, RUS',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Eurockot_Launch_Services',
#      'infoURLs': ['http://www.eurockot.com/',
#       'http://www.youtube.com/user/Eurockot']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 583,
#     'name': 'Rokot / Briz-KM | Swarm A, B, C',
#     'windowstart': 'November 22, 2013 12:02:29 UTC',
#     'windowend': 'November 22, 2013 12:02:29 UTC',
#     'net': 'November 22, 2013 12:02:29 UTC'},
#    'infoURL': 'http://www.esa.int/Our_Activities/Observing_the_Earth/The_Living_Planet_Programme/Earth_Explorers/Swarm/ESA_s_magnetic_field_mission_Swarm',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Swarm_(spacecraft)',
#    'events': None,
#    'infoURLs': ['http://www.esa.int/Our_Activities/Observing_the_Earth/The_Living_Planet_Programme/Earth_Explorers/Swarm/ESA_s_magnetic_field_mission_Swarm'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 35,
#    'name': 'Proba-V and VNREDSat 1A',
#    'description': 'Proba-V maps land cover and monitors vegetation growth across the globe. Launched along with Proba-V are the first Earth observation satellite for Vietnam, VNREDSat 1A, and the first Estonian satellite ESTCube-1. ESTCube-1 is also the first satellite in the world to attempt the use of an electric solar wind sail.',
#    'agencies': [{'id': 27,
#      'name': 'European Space Agency',
#      'abbrev': 'ESA',
#      'countryCode': 'AUT,BEL,CZE,DNK,FIN,FRA,DEU,GRC,IRE,ITA,LUZ,NLD,NOR,POL,PRT,ROU,ESP,SWE,CHE,GBR',
#      'type': 2,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/European_Space_Agency',
#      'infoURLs': ['http://www.esa.int/',
#       'https://www.facebook.com/EuropeanSpaceAgency',
#       'https://twitter.com/esa',
#       'https://www.youtube.com/channel/UCIBaDdAbGlFDeS33shmlD0A']},
#     {'id': 115,
#      'name': 'Arianespace',
#      'abbrev': 'ASA',
#      'countryCode': 'FRA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Arianespace',
#      'infoURLs': ['http://www.arianespace.com',
#       'https://www.youtube.com/channel/UCRn9F2D9j-t4A-HgudM7aLQ',
#       'https://www.facebook.com/ArianeGroup',
#       'https://twitter.com/arianespace',
#       'https://www.instagram.com/arianespace']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 536,
#     'name': 'Vega | Proba-V, VNREDSat 1A, ESTCube-1',
#     'windowstart': 'May 7, 2013 02:06:31 UTC',
#     'windowend': 'May 7, 2013 02:06:31 UTC',
#     'net': 'May 7, 2013 02:06:31 UTC'},
#    'infoURL': 'http://www.esa.int/Our_Activities/Observing_the_Earth/Proba-V/About_Proba-V',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Proba-V',
#    'events': None,
#    'infoURLs': ['http://www.esa.int/Our_Activities/Observing_the_Earth/Proba-V/About_Proba-V',
#     'https://en.wikipedia.org/wiki/VNREDSat_1A',
#     'https://en.wikipedia.org/wiki/ESTCube-1'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 36,
#    'name': 'Arianespace ATV - ISS Cargo Supply Vehicle',
#    'description': 'ESA Spacecraft named Albert Einstein',
#    'agencies': None,
#    'type': 0,
#    'launch': None,
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 37,
#    'name': 'Progress M-19M (51P)',
#    'description': 'The Progress resupply vehicle is an automated, unpiloted version of the Soyuz spacecraft that is used to bring supplies and fuel to the International Space Station.',
#    'agencies': [{'id': 63,
#      'name': 'Russian Federal Space Agency (ROSCOSMOS)',
#      'abbrev': 'RFSA',
#      'countryCode': 'RUS',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Russian_Federal_Space_Agency',
#      'infoURLs': ['http://en.roscosmos.ru/',
#       'https://www.youtube.com/channel/UCOcpUgXosMCIlOsreUfNFiA',
#       'https://twitter.com/Roscosmos',
#       'https://www.facebook.com/Roscosmos']}],
#    'type': 11,
#    'typeName': 'Resupply',
#    'launch': {'id': 532,
#     'name': 'Soyuz-U | Progress M-19M (51P)',
#     'windowstart': 'April 24, 2013 10:12:16 UTC',
#     'windowend': 'April 24, 2013 10:12:16 UTC',
#     'net': 'April 24, 2013 10:12:16 UTC'},
#    'infoURL': '',
#    'wikiURL': 'http://www.nasa.gov/mission_pages/station/structure/elements/progress.html#.V7IZOSiLTIU',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 344,
#    'name': 'Resourcesat-2A',
#    'description': 'Resourcesat-2A is a remote sensing satellite, third in the program of the same name. It is intended to provide data continuity for users as a follow on mission to Resourcesat-2.',
#    'agencies': [{'id': 31,
#      'name': 'Indian Space Research Organization',
#      'abbrev': 'ISRO',
#      'countryCode': 'IND',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Indian_Space_Research_Organization',
#      'infoURLs': ['https://www.isro.gov.in/',
#       'https://twitter.com/ISRO',
#       'https://www.youtube.com/channel/UCw5hEVOTfz_AfzsNFWyNlNg',
#       'https://www.facebook.com/ISRO']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 1060,
#     'name': 'PSLV XL | Resourcesat-2A',
#     'windowstart': 'December 7, 2016 04:30:00 UTC',
#     'windowend': 'December 7, 2016 08:30:00 UTC',
#     'net': 'December 7, 2016 04:54:00 UTC'},
#    'infoURL': 'http://space.skyrocket.de/doc_sdat/resourcesat-2.htm',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': ['http://space.skyrocket.de/doc_sdat/resourcesat-2.htm'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 39,
#    'name': 'CASSIOPE',
#    'description': 'CASSIOPE (Cascade SmallSat and Ionospheric Polar Explorer) is a small satellite mission for Canadian Space Agency to feature the first in a new generation of multi-purpose satellite platforms. It is tasked with a dual mission on scientific research and telecommunications.',
#    'agencies': [{'id': 16,
#      'name': 'Canadian Space Agency',
#      'abbrev': 'CSA',
#      'countryCode': 'CAN',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Canadian_Space_Agency',
#      'infoURLs': ['http://asc-csa.gc.ca/eng/',
#       'https://twitter.com/csa_asc',
#       'https://www.facebook.com/CanadianSpaceAgency',
#       'https://www.instagram.com/canadianspaceagency/',
#       'https://www.linkedin.com/company/9441729/']},
#     {'id': 121,
#      'name': 'SpaceX',
#      'abbrev': 'SpX',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/SpaceX',
#      'infoURLs': ['http://www.spacex.com/',
#       'https://twitter.com/SpaceX',
#       'https://www.youtube.com/channel/UCtI0Hodo5o5dUb67FeUjDeA']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 571,
#     'name': 'Falcon 9 v1.1 | CASSIOPE',
#     'windowstart': 'September 29, 2013 16:00:00 UTC',
#     'windowend': 'September 29, 2013 16:00:00 UTC',
#     'net': 'September 29, 2013 16:00:00 UTC'},
#    'infoURL': 'http://www.asc-csa.gc.ca/eng/satellites/cassiope.asp',
#    'wikiURL': 'https://en.wikipedia.org/wiki/CASSIOPE',
#    'events': None,
#    'infoURLs': ['http://www.asc-csa.gc.ca/eng/satellites/cassiope.asp'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 40,
#    'name': 'Interface Region Imaging Spectrograph (IRIS)',
#    'description': "The Interface Region Imaging Spectrograph (IRIS) is a NASA Small Explorer Mission to observe how solar material moves, gathers energy, and heats up as it travels through a little-understood region in the sun's lower atmosphere.",
#    'agencies': [{'id': 44,
#      'name': 'National Aeronautics and Space Administration',
#      'abbrev': 'NASA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#      'infoURLs': ['http://www.nasa.gov',
#       'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#       'https://twitter.com/nasa',
#       'https://www.facebook.com/nasa']}],
#    'type': 4,
#    'typeName': 'Heliophysics',
#    'launch': {'id': 548,
#     'name': 'Pegasus XL | Interface Region Imaging Spectrograph (IRIS)',
#     'windowstart': 'June 28, 2013 02:27:46 UTC',
#     'windowend': 'June 28, 2013 02:27:46 UTC',
#     'net': 'June 28, 2013 02:27:46 UTC'},
#    'infoURL': 'https://www.nasa.gov/mission_pages/iris/overview/index.html',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Interface_Region_Imaging_Spectrograph',
#    'events': None,
#    'infoURLs': ['https://www.nasa.gov/mission_pages/iris/overview/index.html'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 44,
#    'name': 'O3b FM1, FM2, FM4, FM5',
#    'description': 'The O3b Satellite Constellation is designed for telecommunications and data backhaul from remote locations.',
#    'agencies': [],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 546,
#     'name': 'Soyuz STB/Fregat-MT | O3b FM1, FM2, FM4, FM5',
#     'windowstart': 'June 25, 2013 19:27:03 UTC',
#     'windowend': 'June 25, 2013 19:27:03 UTC',
#     'net': 'June 25, 2013 19:27:03 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/O3b_(satellite)',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-02-24 11:44:47',
#    'payloads': []},
#   {'id': 45,
#    'name': 'Shenzhou-10',
#    'description': "This isthe fifth crewed mission for China's Shenzhou program which lasted 15 days. Shenzhou-10 began its mission by bringing Nie Haisheng, Zhang Xiaoguang and Wang Yaping to the Tiangong-1 space station. During their 12-day stay at the station astronauts conducted space medicine and technological experiments, and Wang Yaping gave a lecture for over 60 million Chinese students. On 23 June undocked from the station and performed manual re-docking procedure, which was one of the objectives of the mission. On 25 June Shenzhou-10 undocked from the station and landed safely on the morning of the next day.",
#    'agencies': [{'id': 88,
#      'name': 'China Aerospace Science and Technology Corporation',
#      'abbrev': 'CASC',
#      'countryCode': 'CHN',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'https://en.wikipedia.org/wiki/China_Aerospace_Science_and_Technology_Corporation',
#      'infoURLs': ['http://english.spacechina.com/',
#       'http://www.cast.cn/item/list.asp?id=1561']}],
#    'type': 5,
#    'typeName': 'Human Exploration',
#    'launch': {'id': 544,
#     'name': 'Long March 2F | Shenzhou-10',
#     'windowstart': 'June 11, 2013 09:38:02 UTC',
#     'windowend': 'June 11, 2013 09:38:02 UTC',
#     'net': 'June 11, 2013 09:38:02 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Shenzhou_10',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 46,
#    'name': 'WGS-6 (USA-244)',
#    'description': 'The United Launch Alliance Delta 4 rocket will launch the sixth Wideband Global SATCOM spacecraft, formerly known as the Wideband Gapfiller Satellite. Built by Boeing, this geostationary communications spacecraft will serve U.S. military forces.',
#    'agencies': [{'id': 124,
#      'name': 'United Launch Alliance',
#      'abbrev': 'ULA',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/United_Launch_Alliance',
#      'infoURLs': ['http://www.ulalaunch.com/',
#       'https://www.youtube.com/channel/UCnrGPRKAg1PgvuSHrRIl3jg',
#       'https://twitter.com/ulalaunch',
#       'https://www.facebook.com/ulalaunch',
#       'https://www.instagram.com/ulalaunch/']},
#     {'id': 165,
#      'name': 'US Army',
#      'abbrev': 'USA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/US_Army',
#      'infoURLs': ['http://www.army.mil',
#       'https://www.facebook.com/USarmy',
#       'https://twitter.com/USArmy',
#       'https://www.youtube.com/USarmy',
#       'https://www.flickr.com/photos/soldiersmediacenter',
#       'https://www.instagram.com/usarmy']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 557,
#     'name': 'Delta IV M+(5,4) | WGS-6 (USA-244)',
#     'windowstart': 'August 8, 2013 00:29:00 UTC',
#     'windowend': 'August 8, 2013 00:29:00 UTC',
#     'net': 'August 8, 2013 00:29:00 UTC'},
#    'infoURL': 'http://www.af.mil/AboutUs/FactSheets/Display/tabid/224/Article/104512/wideband-global-satcom-satellite.aspx',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Wideband_Global_SATCOM',
#    'events': None,
#    'infoURLs': ['http://www.af.mil/AboutUs/FactSheets/Display/tabid/224/Article/104512/wideband-global-satcom-satellite.aspx'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 47,
#    'name': 'ORS 3 and STPSat 3',
#    'description': 'ORS 3 tracks rockets from orbit and can terminate, STPSat3 will host military experiments',
#    'agencies': [],
#    'type': 0,
#    'launch': {'id': 580,
#     'name': 'Minotaur I | ORS-3',
#     'windowstart': 'November 20, 2013 01:15:00 UTC',
#     'windowend': 'November 20, 2013 01:15:00 UTC',
#     'net': 'November 20, 2013 01:15:00 UTC'},
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 48,
#    'name': 'SES-8',
#    'description': 'SES-8 is a geostationary communications satellite, providing broadcasting and network services for South Asia and India.',
#    'agencies': [{'id': 203,
#      'name': 'SES',
#      'abbrev': 'SES',
#      'countryCode': 'LUX',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'https://en.wikipedia.org/wiki/SES_S.A.',
#      'infoURLs': []}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 587,
#     'name': 'Falcon 9 v1.1 | SES-8',
#     'windowstart': 'December 3, 2013 21:41:00 UTC',
#     'windowend': 'December 3, 2013 21:41:00 UTC',
#     'net': 'December 3, 2013 21:41:00 UTC'},
#    'infoURL': 'http://www.ses.com/4629034/ses-8',
#    'wikiURL': 'https://en.wikipedia.org/wiki/SES-8',
#    'events': None,
#    'infoURLs': ['http://www.ses.com/4629034/ses-8'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 49,
#    'name': 'MUOS-2',
#    'description': 'MUOS (Mobile User Objective System) is a next-generation narrowband tactical satellite communications system designed to significantly improve ground communications for U.S. forces on the move.',
#    'agencies': [{'id': 124,
#      'name': 'United Launch Alliance',
#      'abbrev': 'ULA',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/United_Launch_Alliance',
#      'infoURLs': ['http://www.ulalaunch.com/',
#       'https://www.youtube.com/channel/UCnrGPRKAg1PgvuSHrRIl3jg',
#       'https://twitter.com/ulalaunch',
#       'https://www.facebook.com/ulalaunch',
#       'https://www.instagram.com/ulalaunch/']}],
#    'type': 7,
#    'typeName': 'Government/Top Secret',
#    'launch': {'id': 552,
#     'name': 'Atlas V 551 | MUOS-2',
#     'windowstart': 'July 19, 2013 13:00:00 UTC',
#     'windowend': 'July 19, 2013 13:00:00 UTC',
#     'net': 'July 19, 2013 13:00:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Mobile_User_Objective_System',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 50,
#    'name': 'Galileo FOC-1 & Galileo FOC-2',
#    'description': 'These are the first two satellites of the The Galileo constellation is ESAâ€™s satellite navigation system and is expected to be completed by 2020. Galileo will provide Europe with an alternative to the American GPS and Russian GLONASS constellations, but will be interoperable with both systems.',
#    'agencies': [{'id': 27,
#      'name': 'European Space Agency',
#      'abbrev': 'ESA',
#      'countryCode': 'AUT,BEL,CZE,DNK,FIN,FRA,DEU,GRC,IRE,ITA,LUZ,NLD,NOR,POL,PRT,ROU,ESP,SWE,CHE,GBR',
#      'type': 2,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/European_Space_Agency',
#      'infoURLs': ['http://www.esa.int/',
#       'https://www.facebook.com/EuropeanSpaceAgency',
#       'https://twitter.com/esa',
#       'https://www.youtube.com/channel/UCIBaDdAbGlFDeS33shmlD0A']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 312,
#     'name': 'Soyuz STB/Fregat | Galileo FOC-1 & Galileo FOC-2',
#     'windowstart': 'August 22, 2014 12:27:11 UTC',
#     'windowend': 'August 22, 2014 12:27:11 UTC',
#     'net': 'August 22, 2014 12:27:11 UTC'},
#    'infoURL': 'http://www.esa.int/Our_Activities/Navigation/Galileo/What_is_Galileo',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Galileo_(satellite_navigation)#Full_Operational_Capability_.28FOC.29_satellites',
#    'events': None,
#    'infoURLs': ['http://www.esa.int/Our_Activities/Navigation/Galileo/What_is_Galileo'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 51,
#    'name': 'Kounotori 4 (HTV-4)',
#    'description': 'Uncrewed cargo resupply mission to International Space Station delayed from June 2012.',
#    'agencies': [{'id': 37,
#      'name': 'Japan Aerospace Exploration Agency',
#      'abbrev': 'JAXA',
#      'countryCode': 'JPN',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Japan_Aerospace_Exploration_Agency',
#      'infoURLs': ['http://www.jaxa.jp/',
#       'https://www.youtube.com/channel/UCfMIdADo6FQayQCOkLYGhrQ',
#       'https://twitter.com/JAXA_en',
#       'https://www.facebook.com/jaxa.en']}],
#    'type': 11,
#    'typeName': 'Resupply',
#    'launch': {'id': 556,
#     'name': 'H-IIB 304 | Kounotori 4 (HTV-4)',
#     'windowstart': 'August 3, 2013 19:48:46 UTC',
#     'windowend': 'August 3, 2013 19:48:46 UTC',
#     'net': 'August 3, 2013 19:48:46 UTC'},
#    'infoURL': 'http://iss.jaxa.jp/en/htv/mission/htv-4/',
#    'wikiURL': 'https://en.wikipedia.org/wiki/H-II_Transfer_Vehicle',
#    'events': None,
#    'infoURLs': ['http://iss.jaxa.jp/en/htv/mission/htv-4/'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 52,
#    'name': 'Progress M-20M (52P)',
#    'description': 'The Progress resupply vehicle is an automated, unpiloted version of the Soyuz spacecraft that is used to bring supplies and fuel to the International Space Station.',
#    'agencies': [{'id': 63,
#      'name': 'Russian Federal Space Agency (ROSCOSMOS)',
#      'abbrev': 'RFSA',
#      'countryCode': 'RUS',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Russian_Federal_Space_Agency',
#      'infoURLs': ['http://en.roscosmos.ru/',
#       'https://www.youtube.com/channel/UCOcpUgXosMCIlOsreUfNFiA',
#       'https://twitter.com/Roscosmos',
#       'https://www.facebook.com/Roscosmos']}],
#    'type': 11,
#    'typeName': 'Resupply',
#    'launch': {'id': 555,
#     'name': 'Soyuz-U | Progress M-20M (52P)',
#     'windowstart': 'July 27, 2013 20:45:08 UTC',
#     'windowend': 'July 27, 2013 20:45:08 UTC',
#     'net': 'July 27, 2013 20:45:08 UTC'},
#    'infoURL': '',
#    'wikiURL': 'http://www.nasa.gov/mission_pages/station/structure/elements/progress.html#.V7IZOSiLTIU',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 53,
#    'name': 'LADEE',
#    'description': 'NASA\'s Lunar Atmosphere and Dust Environment Explorer (LADEE, pronounced like "laddie") was a robotic mission that orbited the moon to gather detailed information about the lunar atmosphere, conditions near the surface and environmental influences on lunar dust.',
#    'agencies': [{'id': 44,
#      'name': 'National Aeronautics and Space Administration',
#      'abbrev': 'NASA',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#      'infoURLs': ['http://www.nasa.gov',
#       'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#       'https://twitter.com/nasa',
#       'https://www.facebook.com/nasa']}],
#    'type': 0,
#    'launch': {'id': 563,
#     'name': 'Minotaur V | LADEE',
#     'windowstart': 'September 7, 2013 03:27:00 UTC',
#     'windowend': 'September 7, 2013 03:27:00 UTC',
#     'net': 'September 7, 2013 03:27:00 UTC'},
#    'infoURL': 'http://www.nasa.gov/mission_pages/ladee/mission-overview',
#    'wikiURL': 'http://www.nasa.gov/mission_pages/ladee/mission-overview',
#    'events': None,
#    'infoURLs': ['http://www.nasa.gov/mission_pages/ladee/mission-overview'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 54,
#    'name': 'Orbcomm OG2 Mission 1',
#    'description': 'In this flight, the Falcon 9 rocket will deliver the first six of a series of next generation OG2 satellites to an elliptical 750 x 615\nkm low-Earth orbit. The OG2 satellites are commercial\ntelecommunications satellites, built by\nSierra Nevada Corporation and weigh approximately 170 kg each.',
#    'agencies': [{'id': 121,
#      'name': 'SpaceX',
#      'abbrev': 'SpX',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/SpaceX',
#      'infoURLs': ['http://www.spacex.com/',
#       'https://twitter.com/SpaceX',
#       'https://www.youtube.com/channel/UCtI0Hodo5o5dUb67FeUjDeA']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 301,
#     'name': 'Falcon 9 v1.1 | Orbcomm OG2 Mission 1',
#     'windowstart': 'July 14, 2014 15:15:00 UTC',
#     'windowend': 'July 14, 2014 15:15:00 UTC',
#     'net': 'July 14, 2014 15:15:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Orbcomm_(satellite)#Orbcomm-OG2',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 56,
#    'name': 'AEHF-1 (USA-214)',
#    'description': 'This is the first satellite of the Advanced Extremely High Frequency (AEHF) system, which is a series of communications satellites operated by the United States Air Force Space Command. It provides global, survivable, protected communications capabilities for strategic command and tactical warfighters operating on ground, sea and air platforms.',
#    'agencies': [{'id': 161,
#      'name': 'United States Air Force',
#      'abbrev': 'USAF',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/United_States_Air_Force',
#      'infoURLs': ['http://www.af.mil',
#       'https://www.facebook.com/USairforce',
#       'https://twitter.com/USairforce',
#       'https://www.youtube.com/afbluetube',
#       'https://www.instagram.com/usairforce',
#       'https://www.flickr.com/photos/usairforce']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 615,
#     'name': 'Atlas V 531 | AEHF-2 (USA-235)',
#     'windowstart': 'May 4, 2012 18:42:00 UTC',
#     'windowend': 'May 4, 2012 18:42:00 UTC',
#     'net': 'May 4, 2012 18:42:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/USA-214',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 58,
#    'name': 'Gaia',
#    'description': "Gaia's ambitious mission is to chart a three-dimensional map of the Milky Way, in process revealing the composition, formation and evolution of our galaxy.",
#    'agencies': [{'id': 27,
#      'name': 'European Space Agency',
#      'abbrev': 'ESA',
#      'countryCode': 'AUT,BEL,CZE,DNK,FIN,FRA,DEU,GRC,IRE,ITA,LUZ,NLD,NOR,POL,PRT,ROU,ESP,SWE,CHE,GBR',
#      'type': 2,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/European_Space_Agency',
#      'infoURLs': ['http://www.esa.int/',
#       'https://www.facebook.com/EuropeanSpaceAgency',
#       'https://twitter.com/esa',
#       'https://www.youtube.com/channel/UCIBaDdAbGlFDeS33shmlD0A']}],
#    'type': 3,
#    'typeName': 'Astrophysics',
#    'launch': {'id': 591,
#     'name': 'Soyuz STB/Fregat-MT | Gaia',
#     'windowstart': 'December 19, 2013 09:12:19 UTC',
#     'windowend': 'December 19, 2013 09:12:19 UTC',
#     'net': 'December 19, 2013 09:12:19 UTC'},
#    'infoURL': 'http://sci.esa.int/gaia/',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Gaia_(spacecraft)',
#    'events': None,
#    'infoURLs': ['http://sci.esa.int/gaia/'],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 77,
#    'name': 'NROL-67 (USA-250)',
#    'description': 'Classified spacecraft payload for the U.S. National Reconnaissance Office.',
#    'agencies': [{'id': 181,
#      'name': 'National Reconnaissance Office',
#      'abbrev': 'NRO',
#      'countryCode': 'USA',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'https://en.wikipedia.org/wiki/National_Reconnaissance_Office',
#      'infoURLs': ['http://www.nro.gov/',
#       'https://www.facebook.com/NationalReconnaissanceOffice',
#       'https://twitter.com/NatReconOfc',
#       'https://www.youtube.com/c/nationalreconnaissanceoffice']}],
#    'type': 7,
#    'typeName': 'Government/Top Secret',
#    'launch': {'id': 95,
#     'name': 'Atlas V 541 | NROL-67 (USA-250)',
#     'windowstart': 'April 10, 2014 17:45:00 UTC',
#     'windowend': 'April 10, 2014 17:45:00 UTC',
#     'net': 'April 10, 2014 17:45:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/List_of_NRO_launches',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2017-02-21 00:00:00',
#    'payloads': []},
#   {'id': 60,
#    'name': 'Progress M-21M (53P)',
#    'description': 'The Progress resupply vehicle is an automated, unpiloted version of the Soyuz spacecraft that is used to bring supplies and fuel to the International Space Station.',
#    'agencies': [{'id': 63,
#      'name': 'Russian Federal Space Agency (ROSCOSMOS)',
#      'abbrev': 'RFSA',
#      'countryCode': 'RUS',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Russian_Federal_Space_Agency',
#      'infoURLs': ['http://en.roscosmos.ru/',
#       'https://www.youtube.com/channel/UCOcpUgXosMCIlOsreUfNFiA',
#       'https://twitter.com/Roscosmos',
#       'https://www.facebook.com/Roscosmos']}],
#    'type': 11,
#    'typeName': 'Resupply',
#    'launch': {'id': 585,
#     'name': 'Soyuz-U | Progress M-21M (53P)',
#     'windowstart': 'November 25, 2013 20:53:06 UTC',
#     'windowend': 'November 25, 2013 20:53:06 UTC',
#     'net': 'November 25, 2013 20:53:06 UTC'},
# ...
#       'https://www.facebook.com/CanadianSpaceAgency',
#       'https://www.instagram.com/canadianspaceagency/',
#       'https://www.linkedin.com/company/9441729/']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 1200,
#     'name': 'Falcon 9 Block 5 | RADARSAT Constellation',
#     'windowstart': 'June 12, 2019 14:17:00 UTC',
#     'windowend': 'June 12, 2019 14:17:00 UTC',
#     'net': 'June 12, 2019 14:17:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/RADARSAT_Constellation',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-04-12 16:27:05',
#    'payloads': [{'id': 441,
#      'name': 'RADARSAT Constellation Mission',
#      'countryCodes': 'CAN',
#      'weight': '1400.0000',
#      'dimensions': None,
#      'description': "The RADARSAT Constellation Mission is Canada's Earth observation mission consisting of three satellites. They are designed to provide data for maritime surveillance, disaster management and ecosystem monitoring. Each of the spacecraft consists of a bus and a Synthetic Aperture Radar (SAR) payload. There is also a secondary payload, an Automatic Identification System (AIS) for ships, that will be used independently or in conjunction with the SAR. Satellites have an expected lifetime of 7 years.",
#      'total': 3,
#      'type': 0,
#      'agencies': [{'id': 16,
#        'name': 'Canadian Space Agency',
#        'abbrev': 'CSA',
#        'countryCode': 'CAN',
#        'type': 1,
#        'infoURL': None,
#        'wikiURL': 'http://en.wikipedia.org/wiki/Canadian_Space_Agency',
#        'infoURLs': ['http://asc-csa.gc.ca/eng/',
#         'https://twitter.com/csa_asc',
#         'https://www.facebook.com/CanadianSpaceAgency',
#         'https://www.instagram.com/canadianspaceagency/',
#         'https://www.linkedin.com/company/9441729/']}]}]},
#   {'id': 1199,
#    'name': 'Beidou-3 IGSO-1',
#    'description': 'The satellite is a part of the Chinese Beidou (Compass) satellite navigation system.',
#    'agencies': [{'id': 88,
#      'name': 'China Aerospace Science and Technology Corporation',
#      'abbrev': 'CASC',
#      'countryCode': 'CHN',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'https://en.wikipedia.org/wiki/China_Aerospace_Science_and_Technology_Corporation',
#      'infoURLs': ['http://english.spacechina.com/',
#       'http://www.cast.cn/item/list.asp?id=1561']}],
#    'type': 15,
#    'typeName': 'Navigation',
#    'launch': {'id': 1886,
#     'name': 'Long March 3B/E | Beidou-3 IGSO-1',
#     'windowstart': 'April 20, 2019 14:25:00 UTC',
#     'windowend': 'April 20, 2019 15:00:00 UTC',
#     'net': 'April 20, 2019 14:41:04 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/BeiDou_Navigation_Satellite_System',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-04-20 16:43:38',
#    'payloads': []},
#   {'id': 1200,
#    'name': 'Jilin-1 & others',
#    'description': 'The first sea launch of Long March 11 rocket. It carries 7 satellites, which include a new high-resolution Earth observation satellite Jilin-1 and several test satellites, verifying such technologies as sea surface wind measuring and satellite interlink communication.',
#    'agencies': [],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 1927,
#     'name': 'Long March 11 | Jilin-1 & others',
#     'windowstart': 'June 5, 2019 04:06:00 UTC',
#     'windowend': 'June 5, 2019 06:25:00 UTC',
#     'net': 'June 5, 2019 04:06:01 UTC'},
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-06-05 08:42:08',
#    'payloads': []},
#   {'id': 1201,
#    'name': 'Maiden Flight',
#    'description': 'First launch of the new solid-fueled rocket by Chinarocket Co., Ltd., which is a commercial subsidiary of CASC. On this launch Smart Dragon 1 will also carry payloads for four private companies.',
#    'agencies': [{'id': 272,
#      'name': 'Chinarocket Co., Ltd.',
#      'abbrev': 'CHNR',
#      'countryCode': 'CHN',
#      'type': 3,
#      'infoURL': '',
#      'wikiURL': None,
#      'infoURLs': []}],
#    'type': 13,
#    'typeName': 'Test Flight',
#    'launch': {'id': 1929,
#     'name': 'Smart Dragon 1 | Maiden Flight',
#     'windowstart': 'August 17, 2019 04:00:00 UTC',
#     'windowend': 'August 17, 2019 04:30:00 UTC',
#     'net': 'August 17, 2019 04:11:40 UTC'},
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-04-24 16:37:59',
#    'payloads': []},
#   {'id': 1202,
#    'name': 'Tianhui-2-01',
#    'description': 'At 22:52 UTC on April 29, 2019, China used a Long March 4B rocket from the Taiyuan Satellite Launch Center to successfully launch two Tianhui-2-01 satellites. The satellites will be used for scientific experiments, land resource survey, geographic survey and mapping.',
#    'agencies': [{'id': 88,
#      'name': 'China Aerospace Science and Technology Corporation',
#      'abbrev': 'CASC',
#      'countryCode': 'CHN',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'https://en.wikipedia.org/wiki/China_Aerospace_Science_and_Technology_Corporation',
#      'infoURLs': ['http://english.spacechina.com/',
#       'http://www.cast.cn/item/list.asp?id=1561']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 1930,
#     'name': 'Long March 4B | Tianhui-2-01',
#     'windowstart': 'April 29, 2019 22:52:00 UTC',
#     'windowend': 'April 29, 2019 22:52:00 UTC',
#     'net': 'April 29, 2019 22:52:00 UTC'},
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-04-30 07:56:23',
#    'payloads': []},
#   {'id': 1203,
#    'name': 'Starlink Demo',
#    'description': "An initial batch of 60 satellites meant to test Starlink mega-constellation - SpaceX's project for space-based Internet communication system.",
#    'agencies': [{'id': 121,
#      'name': 'SpaceX',
#      'abbrev': 'SpX',
#      'countryCode': 'USA',
#      'type': 3,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/SpaceX',
#      'infoURLs': ['http://www.spacex.com/',
#       'https://twitter.com/SpaceX',
#       'https://www.youtube.com/channel/UCtI0Hodo5o5dUb67FeUjDeA']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 1698,
#     'name': 'Falcon 9 Block 5 | Starlink Demo (0.9)',
#     'windowstart': 'May 24, 2019 02:30:00 UTC',
#     'windowend': 'May 24, 2019 04:00:00 UTC',
#     'net': 'May 24, 2019 02:30:00 UTC'},
#    'infoURL': '',
#    'wikiURL': 'https://en.wikipedia.org/wiki/Starlink_(satellite_constellation)',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-10-11 00:12:12',
#    'payloads': []},
#   {'id': 1204,
#    'name': 'RISAT-2B',
#    'description': 'Satellite imaging mission of ISRO using an active SAR (Synthetic Aperture Radar) imager to provide continuity of service for RISAT-2.',
#    'agencies': [{'id': 31,
#      'name': 'Indian Space Research Organization',
#      'abbrev': 'ISRO',
#      'countryCode': 'IND',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Indian_Space_Research_Organization',
#      'infoURLs': ['https://www.isro.gov.in/',
#       'https://twitter.com/ISRO',
#       'https://www.youtube.com/channel/UCw5hEVOTfz_AfzsNFWyNlNg',
#       'https://www.facebook.com/ISRO']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 1615,
#     'name': 'PSLV-CA | RISAT-2B',
#     'windowstart': 'May 22, 2019 00:00:00 UTC',
#     'windowend': 'May 22, 2019 00:00:00 UTC',
#     'net': 'May 22, 2019 00:00:00 UTC'},
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-04-30 21:03:20',
#    'payloads': []},
#   {'id': 1205,
#    'name': 'RISAT-2BR1 & others',
#    'description': 'Satellite imaging mission of ISRO using an active SAR (Synthetic Aperture Radar) imager to provide continuity of service for RISAT-2. Mission also carries several small satellites for international customers.',
#    'agencies': [{'id': 31,
#      'name': 'Indian Space Research Organization',
#      'abbrev': 'ISRO',
#      'countryCode': 'IND',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Indian_Space_Research_Organization',
#      'infoURLs': ['https://www.isro.gov.in/',
#       'https://twitter.com/ISRO',
#       'https://www.youtube.com/channel/UCw5hEVOTfz_AfzsNFWyNlNg',
#       'https://www.facebook.com/ISRO']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 1616,
#     'name': 'PSLV-QL | RISAT-2BR1 & others',
#     'windowstart': 'December 11, 2019 09:30:00 UTC',
#     'windowend': 'December 11, 2019 11:30:00 UTC',
#     'net': 'December 11, 2019 09:55:00 UTC'},
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-12-07 11:17:40',
#    'payloads': [{'id': 505,
#      'name': 'RISAT-2BR1',
#      'countryCodes': 'IND',
#      'weight': '628.0000',
#      'dimensions': None,
#      'description': 'RISAT-2BR! is an imaging Earth observation satellite carrying an X-band synthetic aperture radar. It is launched into a 37Â° inclined orbit at 555 km orbital height and has a 5 year orbital lifetime.',
#      'total': 1,
#      'type': 0,
#      'agencies': [{'id': 31,
#        'name': 'Indian Space Research Organization',
#        'abbrev': 'ISRO',
#        'countryCode': 'IND',
#        'type': 1,
#        'infoURL': None,
#        'wikiURL': 'http://en.wikipedia.org/wiki/Indian_Space_Research_Organization',
#        'infoURLs': ['https://www.isro.gov.in/',
#         'https://twitter.com/ISRO',
#         'https://www.youtube.com/channel/UCw5hEVOTfz_AfzsNFWyNlNg',
#         'https://www.facebook.com/ISRO']}]},
#     {'id': 506,
#      'name': 'QPS-SAR 1',
#      'countryCodes': 'JPN',
#      'weight': '100.0000',
#      'dimensions': None,
#      'description': 'QPS-SAR 1 is a small synthetic aperture radar Earth observation satellite with a resolution of 1 m.',
#      'total': 1,
#      'type': 0,
#      'agencies': []},
#     {'id': 507,
#      'name': 'Lemur-2',
#      'countryCodes': 'USA',
#      'weight': '4.0000',
#      'dimensions': '0.1 x 0.1 x 0.3',
#      'description': 'Lemur-2 is a constellation of remote sensing cubesats for Spire Global. Satellites carry two payloads for meteorology and ship traffic tracking.',
#      'total': 4,
#      'type': 1,
#      'agencies': [{'id': 214,
#        'name': 'Spire Global',
#        'abbrev': 'SPIRE',
#        'countryCode': 'USA',
#        'type': 3,
#        'infoURL': '',
#        'wikiURL': 'https://en.wikipedia.org/wiki/Spire_Global',
#        'infoURLs': []}]},
#     {'id': 508,
#      'name': 'Duchifat-3',
#      'countryCodes': 'ISR',
#      'weight': '2.3300',
#      'dimensions': '0.1 x 0.1 x 0.34',
#      'description': 'Duchifat-3 is a student-built experimental cubesat. It carries a camera for Earth imaging and an amateur radio payload.',
#      'total': 1,
#      'type': 1,
#      'agencies': []},
#     {'id': 509,
#      'name': '1HOPSat TD',
#      'countryCodes': 'USA',
#      'weight': '22.0000',
#      'dimensions': '0.22 x 0.22 x 0.34',
#      'description': '1HOPSAT (1st-generation High Optical Performance Satellite) is a prototype satellite for the future Hera Systems Earth observation constellation. It is a 12U cubesat carrying an imaging telescope payload.',
#      'total': 1,
#      'type': 1,
#      'agencies': []},
#     {'id': 510,
#      'name': 'PTD 1 (Tyvak-0192)',
#      'countryCodes': 'USA',
#      'weight': '11.0000',
#      'dimensions': '0.1 x 0.25 x 0.3',
#      'description': 'Path Technology Demonstrator 1 (also known as Tyvak-0192) is a 6U-cubesat with a technology demonstration mission.',
#      'total': 1,
#      'type': 1,
#      'agencies': []},
#     {'id': 511,
#      'name': 'COMMTRAIL (Tyvak 0092)',
#      'countryCodes': 'ITA',
#      'weight': None,
#      'dimensions': None,
#      'description': 'COMMTRAIL (also known as Tyvak 0092) is a technology demonstration mission to showcase Search and Rescue capabilities. COMMTRAIL carries a UHF software designed radio equipped with a deployable helix antenna.',
#      'total': 1,
#      'type': 1,
#      'agencies': []}]},
#   {'id': 1206,
#    'name': 'RISAT-2BR2',
#    'description': 'Satellite imaging mission of ISRO using an active SAR (Synthetic Aperture Radar) imager to provide continuity of service for RISAT-2.',
#    'agencies': [{'id': 31,
#      'name': 'Indian Space Research Organization',
#      'abbrev': 'ISRO',
#      'countryCode': 'IND',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Indian_Space_Research_Organization',
#      'infoURLs': ['https://www.isro.gov.in/',
#       'https://twitter.com/ISRO',
#       'https://www.youtube.com/channel/UCw5hEVOTfz_AfzsNFWyNlNg',
#       'https://www.facebook.com/ISRO']}],
#    'type': 1,
#    'typeName': 'Earth Science',
#    'launch': {'id': 1878,
#     'name': 'PSLV-CA | RISAT-2BR2',
#     'windowstart': 'December 1, 2020 00:00:00 UTC',
#     'windowend': 'December 1, 2020 00:00:00 UTC',
#     'net': 'December 1, 2020 00:00:00 UTC'},
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2019-04-30 21:04:41',
#    'payloads': []},
#   {'id': 1207,
#    'name': 'Glonass-M No. 58 (Kosmos 2534)',
#    'description': 'Glonass-M, also known as Uragan-M, are the second generation of Uragan satellite design used for GLONASS satellite navigation system. GLONASS is a Russian space-based navigation system comparable to the similar GPS and Galileo systems. This generation improves on accuracy, power consumption and design life. Each satellite weighs 1415 kg, is equipped with 12 L-band antennas, and has an operational lifetime of 7 years.',
#    'agencies': [{'id': 63,
#      'name': 'Russian Federal Space Agency (ROSCOSMOS)',
#      'abbrev': 'RFSA',
#      'countryCode': 'RUS',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Russian_Federal_Space_Agency',
#      'infoURLs': ['http://en.roscosmos.ru/',
#       'https://www.youtube.com/channel/UCOcpUgXosMCIlOsreUfNFiA',
#       'https://twitter.com/Roscosmos',
#       'https://www.facebook.com/Roscosmos']}],
#    'type': 15,
#    'typeName': 'Navigation',
#    'launch': {'id': 1679,
#     'name': 'Soyuz 2.1b/Fregat-M | Glonass-M No. 58 (Kosmos 2534)',
#     'windowstart': 'May 27, 2019 06:00:00 UTC',
#     'windowend': 'May 27, 2019 08:00:00 UTC',
#     'net': 'May 27, 2019 06:23:00 UTC'},
#    'infoURL': 'http://www.iss-reshetnev.com/spacecraft/spacecraft-navigation/glonass-m',
#    'wikiURL': 'https://en.wikipedia.org/wiki/GLONASS-M',
#    'events': None,
#    'infoURLs': ['http://www.iss-reshetnev.com/spacecraft/spacecraft-navigation/glonass-m'],
#    'changed': '2020-01-27 14:26:05',
#    'payloads': []},
#   {'id': 1208,
#    'name': 'Meridian-M No.18',
#    'description': 'The Meridian series of communications satellites is reported to be the replacement for all the Molniya-1T, the Molniya-3 and Molniya-3K satellite series and possibly also for the communication component of the Parus. They are launched into highly eccentric Molniya-orbits.\nMeridian is the highly eccentric orbit (HEO) component of the Integrated Satellite Communications System (ISSS), where they work in conjunction with the geostationary Raduga-1M (Globus-M) satellites. The bus structure is reportedly pressurized, possibly based on the Uragan-M bus. Meridian satellites carry three transponders operating in different frequency bands.',
#    'agencies': [{'id': 63,
#      'name': 'Russian Federal Space Agency (ROSCOSMOS)',
#      'abbrev': 'RFSA',
#      'countryCode': 'RUS',
#      'type': 1,
#      'infoURL': None,
#      'wikiURL': 'http://en.wikipedia.org/wiki/Russian_Federal_Space_Agency',
#      'infoURLs': ['http://en.roscosmos.ru/',
#       'https://www.youtube.com/channel/UCOcpUgXosMCIlOsreUfNFiA',
#       'https://twitter.com/Roscosmos',
#       'https://www.facebook.com/Roscosmos']}],
#    'type': 10,
#    'typeName': 'Communications',
#    'launch': {'id': 1661,
#     'name': 'Soyuz 2.1a/Fregat-M | Meridian-M No.18',
#     'windowstart': 'July 30, 2019 05:00:00 UTC',
#     'windowend': 'July 30, 2019 08:00:00 UTC',
#     'net': 'July 30, 2019 05:56:00 UTC'},
#    'infoURL': '',
#    'wikiURL': '',
#    'events': None,
#    'infoURLs': [],
#    'changed': '2020-01-26 14:55:19',
#    'payloads': []},
#   ...],
#  'total': 1117,
#  'count': 1117,
#  'offset': 0}

# %%
launch_statuses_raw = requests.get(BASE_URL + "launchstatus?limit=2000&mode=verbose").json()
agency_types_raw = requests.get(BASE_URL + "agencytype?limit=1000&mode=verbose").json()
mission_types_raw = requests.get(BASE_URL + "missiontype?limit=2000&mode=verbose").json()
payload_types_raw = requests.get(BASE_URL + "payloadtype?limit=2000&mode=verbose").json()

payload_types_raw
# Out:
# {'types': [{'id': 0,
#    'name': 'Satellite',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 1,
#    'name': 'Cubesat',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 2,
#    'name': 'Supplies',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 3,
#    'name': 'Crew',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 4,
#    'name': 'Probe',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 5,
#    'name': 'Rover',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 6,
#    'name': 'Lander',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 7,
#    'name': 'Habitat',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 8,
#    'name': 'Telescope',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'},
#   {'id': 9,
#    'name': 'Other',
#    'description': '',
#    'changed': '2017-02-21 00:00:00'}],
#  'total': 10,
#  'count': 10,
#  'offset': 0}

# %%
db = Database("launchlibrary.db")

pads = db["pads"]
locations = db["locations"]

agencies = db["agencies"]

rockets = db["rockets"]
families = db["rocketfamilies"]

missions = db["missions"]
payloads = db["payloads"]

launches = db["launches"]

# %%
agency_types = {t["id"]: t["name"].upper() for t in agency_types_raw["types"]}
status_types = {t["id"]: t["name"].upper() for t in launch_statuses_raw["types"]}
mission_types = {t["id"]: t["name"].upper() for t in mission_types_raw["types"]}
payload_types = {t["id"]: t["name"].upper() for t in payload_types_raw["types"]}
payload_types
# Out:
# {0: 'SATELLITE',
#  1: 'CUBESAT',
#  2: 'SUPPLIES',
#  3: 'CREW',
#  4: 'PROBE',
#  5: 'ROVER',
#  6: 'LANDER',
#  7: 'HABITAT',
#  8: 'TELESCOPE',
#  9: 'OTHER'}

# %%
def ids_to_m2m(cur, ids, lookup, m2m_table):
    for _id in ids:
        cur.m2m(lookup.name, lookup={"id": _id}, m2m_table=m2m_table)

# %%
print(agencies_raw["agencies"][0].keys())
_agencies = glom(agencies_raw["agencies"],
    [{
        "id":  "id",
        "name":"name",
        "countryCode": "countryCode",
        'abbrev': "abbrev", 
        'type': ("type", lambda t: agency_types[t]),
        'islsp': "islsp", 
#         'changed': ("changed", parse_dt),
        'infoURL': "infoURL", 
        'wikiURL': "wikiURL", 
        
    }]
)
agencies.upsert_all(_agencies, pk="id")
# Out:
# dict_keys(['id', 'name', 'countryCode', 'abbrev', 'type', 'infoURL', 'wikiURL', 'infoURLs', 'islsp', 'changed'])
# <Table agencies (id, name, countryCode, abbrev, type, islsp, infoURL, wikiURL)>

# %%
print(locations_raw["locations"][0].keys())
_locations = glom(locations_raw["locations"],
    [{
        "id":  "id",
        "name":"name",
#         'changed': ("changed", parse_dt),
        'infoURL': "infoURL", 
        'wikiURL': "wikiURL", 
        
    }]
)

locations.upsert_all(_locations, pk="id")
# Out:
# dict_keys(['id', 'name', 'countrycode', 'infoURL', 'wikiURL', 'infoURLs', 'changed'])
# <Table locations (id, name, infoURL, wikiURL)>

# %%
print(pads_raw["pads"][0].keys())
# droping agencies (its many to many relation), anf info URLs
_pads = copy(pads_raw["pads"])
_pads = glom(_pads,
    [{
        "id":  "id",
        "name":"name",
        "padType": "padType",
        'latitude': "latitude", 
        'longitude': "longitude", 
        'retired': "retired", 
        'locationId': "locationid", 
        'agencies': 'agencies',
#         'changed': ("changed", parse_dt),
        'infoURL': "infoURL", 
        'wikiURL': "wikiURL", 
        
    }]
)
# pads.upsert_all(_pads, pk="id",
#     foreign_keys=[
#     ("locationId", locations.name, "id")
# ])

for r in _pads:
    a_ids = glom(r.pop("agencies"), ["id"], default=[])
    print(a_ids)
    cur = pads.upsert(r, pk="id", foreign_keys=[("locationId", locations.name, "id")])
    if a_ids is not None:
        ids_to_m2m(cur, a_ids, agencies, "pad_agency")
# Out:
# dict_keys(['id', 'name', 'padType', 'latitude', 'longitude', 'mapURL', 'retired', 'locationid', 'agencies', 'infoURL', 'wikiURL', 'infoURLs', 'changed'])
# [160]
# [160]
# [160]
# [160]
# [162, 17]
# [162, 17]
# [17, 88]
# [17, 88]
# [100]
# [147]
# [162, 17]
# [162, 17]
# []
# [162, 17]
# [115, 4]
# [37]
# [115]
# [115]
# []
# []
# [34]
# [34]
# [36]
# [37]
# [37]
# [37]
# [37]
# [163, 63]
# [163, 63]
# [115]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163, 63]
# [163]
# [163]
# [163]
# [163]
# [163]
# [163]
# [163]
# [163]
# [163]
# [163]
# [63]
# [63]
# [63]
# [31]
# [63]
# [80]
# [161, 44]
# [161, 44]
# [124, 161, 44]
# [165, 44]
# [161]
# [163]
# [161]
# [161]
# [161, 44]
# [161, 44]
# [161]
# [161]
# [161, 166, 44]
# [161, 166, 44]
# [161, 44]
# [161, 44]
# [161, 165]
# [161]
# [161, 44]
# [161, 44, 167]
# [161, 44, 167]
# [124, 161, 44]
# [121]
# [124, 161]
# [161, 167]
# [121, 44]
# [44]
# [124, 161]
# [161]
# [124, 161]
# [161]
# [141]
# [161]
# [161]
# [161]
# []
# [161]
# [121, 161]
# [161]
# [161]
# [161]
# [161]
# [161]
# [141]
# [44]
# [44]
# [44]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [163]
# [63]
# []
# []
# []
# []
# [44]
# []
# []
# []
# []
# [17, 88]
# [17]
# [31]
# [31]
# [115]
# [17]
# [95]
# [95]
# [166]
# [41]
# []
# [17, 88, 184]
# [63]
# []
# [40]
# [179, 100]
# [179, 100]
# [179, 100]
# []
# [100]
# [37]
# [63]
# [37]
# []
# []
# [17, 162, 177]
# [34]
# [147]
# []
# []
# []
# []
# [63]
# []
# [17, 162]
# []
# []
# [147]

# %%
print(families_raw["RocketFamilies"][0].keys())
_families = copy(families_raw["RocketFamilies"])
_families = glom(_families,
    [{
        "id":  "id",
        "name":"name",
        "agencies": "agencies", #TODO: m2m
#         'changed': ("changed", parse_dt),
        
    }]
)
# _families[0]
# families.upsert_all(_families, pk="id",
# )
for r in _families:
    a_ids = glom(r.pop("agencies"), ["id"], default=[])
    print(a_ids)
    cur = families.upsert(r, pk="id")
    if a_ids is not None:
        ids_to_m2m(cur, a_ids, agencies, "rocketfamily_agency")
# Out:
# dict_keys(['id', 'name', 'agencies', 'changed'])
# [96, 63]
# [112, 154]
# [103, 66]
# [96, 63]
# [96]
# [111, 63]
# [66, 103]
# [125]
# [112, 122, 63]
# [82, 156]
# [124, 82, 106]
# [124, 80]
# [121]
# [156, 135]
# [100]
# [44, 153, 102, 80]
# [101, 82]
# [82]
# [124]
# [115, 116, 81, 27]
# [98]
# [37, 98, 98]
# [37]
# [157]
# [37]
# [87]
# [158]
# [179]
# [179]
# [31]
# [112, 154, 96]
# [88]
# [31]
# [115, 159, 27]
# [96]
# [37, 98]
# []
# []
# [37]
# [103]
# [147]
# []
# []
# []
# []
# []
# []
# [82]
# [31]
# []
# [44]
# []
# []
# []
# []
# [88]
# [88]
# [88]
# [88]
# [88]
# [88]
# [88]
# []
# []
# []
# [96, 63]
# []
# []
# []
# [34]
# [95]
# []
# [44]
# []
# [111, 63]
# [44]
# []
# [40]
# []
# []
# []
# [96]
# []
# []
# []
# [124, 141]
# [37, 98]
# [119, 125]
# [133, 135]
# [141]
# [37]
# [96]
# [188]
# [188]
# [179, 156]
# [199]
# [201]
# [34]
# [31]
# [259]
# [44]
# [263]
# [265]
# [266]
# [272]
# [274]
# [282]
# [257]
# [285]
# [34]

# %%
print(rockets_raw["rockets"][0].keys())
_rockets = glom(rockets_raw["rockets"],
    [{
        "id":  "id",
        "name":"name",
        "configuration": "configuration",
        'defaultPads': "defaultPads", # TODO m2m
        'familyId': "family.id", 
#         'changed': ("changed", parse_dt),
        'infoURL': "infoURL", 
        'wikiURL': "wikiURL", 
        'imageURL': "imageURL",
    }]
)
print(_rockets[0])
for r in _rockets:
    default_pads = r.pop("defaultPads")
    
    cur = rockets.upsert(r, pk="id",
        foreign_keys=[
        ("familyId", families.name, "id")
    ])
    
    # add m2m relation between pads and rockets
    if default_pads is not None:
        default_pads = (int(p) for p in filter(None, set(default_pads.replace(" ", "").split(","))))
        ids_to_m2m(cur, default_pads, pads, "rocket_defaultpad")
# Out:
# dict_keys(['id', 'name', 'configuration', 'defaultPads', 'family', 'infoURL', 'wikiURL', 'infoURLs', 'imageSizes', 'imageURL', 'changed'])
# {'id': 1, 'name': 'Falcon 9 v1.1', 'configuration': '9 v1.1', 'defaultPads': '84,100', 'familyId': 13, 'infoURL': None, 'wikiURL': 'http://en.wikipedia.org/wiki/Falcon_9', 'imageURL': 'https://launchlibrary1.nyc3.digitaloceanspaces.com/RocketImages/Falcon9v1.1.jpg_1280.jpg'}

# %%
_launches = launches_raw["launches"]
print(_launches[0].keys()) # TODO add rest of the keys
_launches = glom(_launches,
    [{
        "id":  "id",
        "name":"name",
        'rocketId': "rocket.id", 
        'lspId': "lsp.id",
        "padId": "location.pads.0.id",
        "status": ("status", lambda t: status_types[t]),
        "windowstart": ("isostart", parse_dt),
        'windowend': ("isoend", parse_dt), 
        "net": ("isonet", parse_dt),
#         'changed': ("changed", parse_dt),
        'infoURL': "infoURL", 
    }]
)
pprint(_launches[0])
launches.upsert_all(_launches, pk="id",
    foreign_keys=[
        ("rocketId", rockets.name, "id"),
        ("lspId", agencies.name, "id"),
        ("padId", pads.name, "id")
])
# Out:
# dict_keys(['id', 'name', 'windowstart', 'windowend', 'net', 'wsstamp', 'westamp', 'netstamp', 'isostart', 'isoend', 'isonet', 'status', 'inhold', 'tbdtime', 'vidURLs', 'vidURL', 'infoURLs', 'infoURL', 'holdreason', 'failreason', 'tbddate', 'probability', 'hashtag', 'changed', 'location', 'rocket', 'missions', 'lsp'])
# {'id': 1829,
#  'infoURL': None,
#  'lspId': 161,
#  'name': 'Atlas LV-3A | Samos 2',
#  'net': datetime.datetime(1961, 1, 31, 20, 21, 19, tzinfo=tzutc()),
#  'padId': 99,
#  'rocketId': 193,
#  'status': 'SUCCESS',
#  'windowend': datetime.datetime(1961, 1, 31, 20, 21, 19, tzinfo=tzutc()),
#  'windowstart': datetime.datetime(1961, 1, 31, 20, 21, 19, tzinfo=tzutc())}
# <Table launches (id, name, rocketId, lspId, padId, status, windowstart, windowend, net, infoURL)>

# %%
print(missions_raw["missions"][0].keys())

_missions = glom(missions_raw["missions"],
    [{
        "id":  "id",
        "name":"name",
        "description": "description",
        "agencies": "agencies",
#         'changed': ("changed", parse_dt),
        "type": ("type", lambda t: mission_types.get(t, None)),
        'infoURL': "infoURL", 
        'wikiURL': "wikiURL", 
    }],
)
pprint(_missions[0])
# pprint(glom(missions_raw["missions"], ["type"]))

for r in _missions:
    a_ids = glom(r.pop("agencies"), ["id"], default=[])
    print(a_ids)
    cur = missions.upsert(r, pk="id")
    if a_ids is not None:
        ids_to_m2m(cur, a_ids, agencies, "mission_agency")
# Out:
# dict_keys(['id', 'name', 'description', 'agencies', 'type', 'typeName', 'launch', 'infoURL', 'wikiURL', 'events', 'infoURLs', 'changed', 'payloads'])
# {'agencies': [{'abbrev': 'NASA',
#                'countryCode': 'USA',
#                'id': 44,
#                'infoURL': None,
#                'infoURLs': ['http://www.nasa.gov',
#                             'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#                             'https://twitter.com/nasa',
#                             'https://www.facebook.com/nasa'],
#                'name': 'National Aeronautics and Space Administration',
#                'type': 1,
#                'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration'}],
#  'description': 'Designed to image high-energy X-ray radiation, the Nuclear '
#                 'Spectroscopic Telescope Array (NuSTAR) is tasked with '
#                 'surveying regions surrounding the center of own Milky Way '
#                 'Galaxy and performing deep observations of the extragalactic '
#                 'sky, studying black holes and supernovas.',
#  'id': 5,
#  'infoURL': 'http://www.nasa.gov/mission_pages/nustar/overview/index.html',
#  'name': 'Nuclear Spectroscopic Telescope Array (NuSTAR)',
#  'type': 'ASTROPHYSICS',
#  'wikiURL': 'https://en.wikipedia.org/wiki/NuSTAR'}
# [44]
# [124, 165]
# [203]
# [44]
# [44]
# [44]
# [204]
# [31, 46]
# []
# []
# [121]
# []
# [63]
# [17]
# [44]
# [124]
# [44, 66]
# [6, 66]
# [204]
# [117]
# [27, 115]
# []
# [63]
# [31]
# [16, 121]
# [44]
# []
# [88]
# [124, 165]
# []
# [203]
# [124]
# [27]
# [37]
# [63]
# [44]
# [121]
# [161]
# [27]
# [181]
# [63]
# [1]
# [161]
# [44]
# [63, 44, 37]
# []
# [124]
# [165]
# []
# []
# []
# [124]
# []
# [44]
# []
# [63]
# []
# [115]
# [31]
# []
# [27, 115]
# [63]
# []
# []
# []
# []
# [124]
# []
# [124, 181]
# []
# []
# []
# []
# []
# [121]
# [124]
# [44, 121]
# [175, 63]
# [37]
# [179, 44]
# [206]
# []
# [63]
# [161]
# [44, 121]
# [124]
# [37]
# []
# []
# [27]
# [121, 44]
# [27]
# [124]
# [63]
# []
# [3]
# [37]
# [31]
# [124, 165]
# [88]
# [206]
# [205]
# [124]
# []
# [161]
# [203]
# [44]
# [63]
# [124]
# [204, 207]
# [63]
# [37]
# [177]
# [31]
# [31]
# [117, 27]
# []
# [179, 44]
# [63]
# [2]
# [124]
# [181]
# [63]
# []
# []
# [27, 27]
# [121]
# [27, 63]
# [17]
# [44, 44]
# []
# [78]
# [206]
# [178]
# [124]
# [124]
# []
# [63]
# [37]
# [31]
# [31]
# [181]
# [124]
# [44]
# [44]
# [203]
# []
# [44]
# [121, 44, 140]
# [44, 63]
# [63]
# [124]
# [204]
# [63]
# [63]
# [63]
# []
# [121]
# []
# [17, 27, 37]
# []
# [44]
# [17]
# [206]
# []
# [27, 115]
# []
# [121]
# []
# [27]
# [55]
# []
# [202]
# [202]
# [49]
# [88]
# [124]
# []
# [66]
# [66]
# [44]
# [44]
# [66]
# []
# [44]
# []
# []
# [44]
# [44]
# [66]
# [66]
# [66]
# [44]
# [44]
# [44]
# [44]
# [66]
# [66]
# [66]
# [121, 181]
# [31]
# [44]
# [44]
# [44]
# [66]
# [66]
# [44]
# [44]
# [66]
# [44]
# [44]
# [44]
# [66]
# [66]
# [44]
# [63]
# []
# [44, 63]
# [31]
# [31]
# [44]
# [6]
# [63, 44, 182]
# [6]
# [63, 44, 27]
# [4]
# [27, 63, 44]
# [44, 63]
# [63, 44]
# [44, 63]
# [44, 27, 63]
# [44, 63]
# [16, 44, 63]
# [44, 63]
# [44, 37, 63]
# [44, 63]
# [63, 44]
# [37, 44, 63]
# [6]
# [44, 63]
# [4]
# [2]
# [63, 44]
# [4]
# [3]
# [6]
# [1]
# [63, 44]
# [63, 44]
# [17]
# []
# [63]
# [63, 44]
# [63, 44]
# [63, 44]
# [63, 44, 27]
# [63, 44, 27]
# [63, 44, 27]
# [44, 63, 27]
# [121]
# [44]
# []
# [115]
# [121]
# [63]
# [161]
# [31]
# [206]
# [8]
# [17]
# []
# [37]
# [37]
# [37]
# [37]
# [124]
# [124]
# [63, 44]
# [124, 165]
# [1]
# [1]
# [203]
# [203]
# [203]
# [203, 207]
# [203]
# [203]
# [161]
# [124]
# [63]
# [63]
# [63]
# [121]
# [83, 118]
# [203]
# [17]
# [17]
# [115]
# [27, 117]
# [63]
# [175]
# [204]
# [115]
# [179]
# []
# [198]
# [31]
# []
# [121]
# [44]
# [17]
# [17, 88]
# [88, 17]
# [88, 17]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [17]
# [88]
# [37]
# [66]
# [66]
# [17]
# [95]
# [63, 44, 27]
# [27]
# [17]
# [147]
# [44]
# [44]
# [44]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [124]
# [66]
# [44]
# [44]
# [44]
# [17]
# [204]
# []
# []
# []
# [124]
# [44, 124]
# [124, 161]
# [124, 161]
# [161]
# [161]
# [115]
# []
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [37]
# [115]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [88]
# []
# [88]
# [115]
# [17]
# [17]
# [31]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [66]
# [63]
# [46, 63]
# [63]
# [63]
# [63]
# [63]
# [63, 27]
# [44]
# [63]
# [63]
# [27, 63]
# [63, 27]
# [63]
# [27]
# [63]
# [63, 27]
# [63]
# [63, 44]
# [63, 44]
# [63, 44, 27]
# [63, 44, 27]
# [206]
# [17]
# [17]
# [17]
# []
# [115]
# [27, 115]
# [115]
# [98]
# [17]
# [63]
# [203]
# [63]
# [63]
# [31]
# [63]
# [182, 107]
# [63]
# [63]
# [63]
# [63]
# [63]
# [63]
# [63]
# [63]
# [63]
# [44, 100]
# [44, 100]
# [63]
# [63]
# [44]
# [44]
# [121, 44]
# [44]
# [27]
# [44]
# [37, 63, 44]
# [118]
# [165]
# [27, 115]
# [204]
# [206]
# [98]
# [31]
# [17, 184]
# [17]
# [121]
# [124]
# [88]
# [4]
# [100]
# [100]
# [100]
# [121]
# [121]
# [121]
# [44]
# [122]
# [44]
# [115]
# [205]
# [44]
# [37]
# [37]
# [83]
# [88]
# [15]
# [204, 205]
# [17]
# [147]
# [175]
# [175]
# [181]
# [181]
# [181]
# [181]
# [181]
# [181]
# [181]
# [181]
# [181]
# [181]
# [181]
# [124]
# [161]
# [161]
# [161]
# [161]
# [175]
# [202]
# [46]
# [37]
# [203]
# [202]
# []
# []
# []
# []
# [63]
# [63]
# [206]
# [203]
# [44]
# []
# []
# [37]
# [202]
# [202]
# [121, 202]
# [202]
# [203]
# [63]
# [179]
# [44]
# [44]
# [44]
# [44]
# [44]
# [161]
# [11, 177]
# [37]
# [31]
# [121]
# [118]
# [27]
# [27]
# [27, 44]
# [44]
# []
# [37]
# [117, 27]
# [17]
# [121]
# [175]
# [37]
# [175]
# [203]
# [181, 124]
# [121]
# []
# [31]
# [44]
# []
# []
# [27]
# [44]
# [44]
# []
# []
# []
# [98]
# [44]
# [59]
# []
# [63]
# [44]
# []
# [44]
# [31]
# [204]
# [208]
# []
# []
# []
# []
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [201]
# []
# []
# [44]
# []
# []
# [27]
# [161]
# [208]
# [161]
# []
# [181]
# [44]
# [36]
# [44]
# [211]
# [44]
# [161]
# [161]
# [36]
# [161]
# [161]
# [44]
# [44, 46]
# [211]
# [36]
# [181]
# []
# [44]
# [161]
# [213]
# []
# [161]
# [212]
# [211]
# [161]
# [44]
# [161]
# [161, 166]
# [161]
# [181]
# [181]
# []
# [161]
# [44]
# [210]
# []
# [206]
# []
# []
# [175]
# [36]
# [44]
# [17]
# [37]
# [280]
# [34]
# [98]
# [31]
# [31]
# [37]
# []
# [44]
# [27]
# [27]
# [63]
# [63]
# [63]
# [27, 63]
# []
# [31, 229]
# []
# [163]
# [63]
# [27]
# []
# [115, 27]
# [27]
# [190, 225]
# [203, 91]
# [84, 226, 227]
# [203, 91, 229]
# [230, 229]
# [27, 230]
# [27]
# [229, 231]
# [229, 232]
# [233, 46]
# [190, 226]
# [230]
# [27]
# [208]
# [233, 46, 33]
# [115, 27]
# [235]
# [233, 226]
# [236, 237]
# [190, 27]
# [238, 239]
# [239, 235]
# [231, 233, 226]
# [236, 240, 228]
# [241, 203]
# [242, 190]
# [203, 206]
# [243, 230]
# [206, 240]
# [242, 244]
# [245, 231, 206]
# [27]
# [244, 246]
# [247, 242]
# [207, 248]
# [207, 231]
# [229]
# [229, 203, 233]
# [27, 44]
# []
# [231, 240]
# [250]
# [203]
# [233]
# [203]
# [207]
# [245]
# [229, 230]
# [206, 255]
# [250]
# [27]
# [251, 206]
# [190]
# [203, 230]
# [27]
# [231, 246]
# [249, 232]
# [206, 255]
# [203, 31]
# [233]
# [81, 256]
# [250, 252]
# [27]
# [205, 190]
# [229, 31]
# [233]
# [27]
# [252, 240]
# [236, 31]
# [254, 253]
# [236]
# []
# [27]
# [44]
# [27, 232]
# [27]
# [175]
# [175]
# []
# []
# [263]
# []
# [63]
# []
# []
# [193]
# [63]
# []
# [44]
# []
# [107]
# [63, 27]
# [37]
# []
# []
# [199]
# []
# []
# [31]
# [44]
# [44]
# [31]
# [31]
# [31]
# [31]
# [31]
# []
# []
# [44]
# []
# [63]
# [63]
# [63]
# [63]
# [88]
# [41]
# []
# [121, 44]
# []
# [37]
# []
# [175]
# [63]
# []
# []
# [257, 44]
# [88]
# []
# []
# [44]
# [233]
# [41]
# [115]
# [44]
# [16]
# [36]
# []
# [273]
# []
# [161]
# [175]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [257, 44]
# [63]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# [44]
# []
# []
# [63]
# [184]
# [88]
# [233]
# [233]
# []
# [121]
# [27]
# [88]
# []
# [34]
# [31, 269]
# [34]
# [265]
# [266]
# [267, 83]
# [165]
# [207]
# []
# [257, 44]
# []
# [269]
# [88]
# [36]
# [31]
# [161]
# [161]
# []
# [44]
# [44]
# [16]
# [88]
# []
# [272]
# [88]
# [121]
# [31]
# [31]
# [31]
# [63]
# [63]
# []
# [17]
# []
# [275]
# [229, 236]
# []
# [63]
# [17]
# [44]
# [44]
# [63]
# []
# [175]
# []
# []
# [274]
# []
# [121]
# [121]
# [161]
# [161]
# [88]
# [37]
# [37]
# [115]
# []
# [63]
# [229, 257]
# []
# [175]
# []
# []
# [88]
# []
# []
# []
# []
# [31]
# [44, 80]
# [44, 80]
# [44, 121]
# [27]
# [27, 37]
# []
# []
# []
# []
# [27]
# []
# []
# []
# [63]
# []
# [63]
# []
# [231]
# []
# [88]
# []
# [193]
# [121]
# [121]
# [98]
# [181]
# [257, 44]
# []
# []
# [285]
# [231, 41]
# [44]
# []
# [44]
# [44]
# []
# [44]
# [88]
# [88]
# [121]
# [280]
# []
# [161]
# [49]
# []
# [44, 181]
# []
# []
# [88]
# []
# [267]
# [63]
# [44, 63]
# [80]
# [121]
# []
# [161]
# [121]
# [80, 44, 27]
# [121, 44, 27]
# [175]
# [121]
# []
# []
# [121]
# []
# []
# []
# [17]
# []
# []
# []
# [44]
# [181]
# [63]
# []
# [206, 230, 257]
# []
# []

# %%
# this won't work because some dims are 2D
def split_dims(p):
    if p["dimensions"] is not None:
        x, y, z = (float(d) for d in p["dimensions"].split("x"))
    else:
        x = y = z = None
    del p["dimensions"]
    p["dimX"] = x
    p["dimY"] = y
    p["dimZ"] = z
    

_payloads = flatten(glom(missions_raw["missions"],
    ["payloads"],
))
print(_payloads[0].keys())

payload_mission_id = {}
for m in (glom(missions_raw["missions"], [{"missionId":"id", "payloads": "payloads"}],)):
    for p in m["payloads"]:
        payload_mission_id[p["id"]] = m["missionId"]
    
_payloads = glom(_payloads,
    [{
        "id": "id",
        "name": "name",
        'countryCodes': 'countryCodes',
        'weight': ('weight', lambda f: float(f) if f is not None else f),
        'dimensions': "dimensions",
        "agencies": "agencies",
        'description': 'description',
        "total": "total",
        "type": ("type", lambda t: payload_types.get(t, None)), # TODO: WTF is this
        "missionId": ("id", lambda i: payload_mission_id[i]),
    }]
)
# _payloads = [split_dims(p) for p in _payloads]
# payloads.upsert_all(_payloads, pk="id",
#     foreign_keys=[
#         ("missionId", missions.name, "id"),
# ])

for r in _payloads:
    a_ids = glom(r.pop("agencies"), ["id"], default=[])
    print(a_ids)
    cur = payloads.upsert(r, pk="id", foreign_keys=[("missionId", missions.name, "id"),])
    if a_ids is not None:
        ids_to_m2m(cur, a_ids, agencies, "payload_agency")
# Out:
# dict_keys(['id', 'name', 'countryCodes', 'weight', 'dimensions', 'description', 'total', 'type', 'agencies'])
# [247]
# []
# []
# [27, 63]
# []
# [202]
# [202]
# [49]
# []
# [278]
# [29]
# []
# [27]
# [161]
# [260]
# [161]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [260]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [198]
# [276]
# []
# [276]
# []
# [203]
# [44]
# []
# [202]
# [203]
# [202]
# []
# [203]
# []
# []
# [44]
# []
# []
# []
# []
# []
# [44]
# []
# []
# []
# []
# []
# [202]
# [44, 29]
# [202]
# [202]
# [202]
# [17, 36]
# [31]
# [37]
# [37]
# [251]
# [203]
# []
# [121]
# []
# []
# []
# []
# []
# [31]
# [31]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [44]
# [29, 44]
# [29, 44]
# []
# []
# [44, 44]
# []
# []
# []
# []
# []
# []
# [161]
# [55, 210]
# [44]
# [107]
# []
# []
# []
# []
# [44]
# []
# []
# []
# []
# []
# []
# []
# [181]
# [44]
# [36]
# [44]
# [211]
# [44]
# [161]
# [161]
# [36]
# [161]
# [161]
# [44]
# [44, 46]
# [211]
# [36]
# [181]
# []
# [44]
# [161]
# [212]
# []
# [161]
# [161]
# [211]
# [161]
# [44]
# [161]
# [161]
# [161, 166]
# [166]
# [161]
# [161]
# [161]
# [181]
# [161]
# [181]
# []
# [161]
# [44]
# [44]
# [210]
# []
# [206]
# [214]
# [224]
# []
# []
# []
# []
# []
# [264]
# [37]
# []
# []
# []
# []
# []
# [280]
# [31]
# [27]
# [37]
# [27, 44]
# []
# []
# [229]
# [31]
# [27]
# [27]
# [27]
# [27]
# [27]
# [27]
# [27]
# [190]
# [225]
# [203]
# [203]
# [206]
# [84]
# [227]
# [227]
# [203]
# [203]
# [228]
# [229]
# [230]
# [27]
# [230]
# [27]
# [229]
# [231]
# [229]
# [27]
# [233]
# [229]
# [46]
# [190]
# [226]
# [240]
# [230]
# [27]
# [27]
# [208]
# [203]
# [46]
# [233]
# [46]
# [33]
# []
# [27]
# [27]
# [235]
# [233]
# [206]
# [236]
# [237]
# [190]
# [27, 232]
# [238]
# [229]
# [229]
# [235]
# [231]
# [233]
# [236]
# [240]
# [228]
# [241]
# [203]
# [242]
# [190]
# [203]
# [206]
# [243]
# [230]
# [206]
# [240]
# [242]
# [244]
# [245]
# [206]
# [81]
# [247]
# [207]
# [248]
# [203]
# [231]
# [229]
# [229]
# [229]
# [27, 44]
# [27]
# []
# [231]
# [240]
# [250]
# []
# [203]
# []
# [233]
# [203]
# []
# [207]
# [41]
# [245]
# []
# [229]
# [230]
# [206]
# [255]
# [250]
# []
# [276]
# [27]
# [251]
# [206]
# []
# [190]
# [203]
# [230, 231]
# [27]
# [231]
# [246]
# [249]
# [27]
# [206]
# [255]
# [203]
# [31]
# [244]
# [229]
# [81]
# [256]
# [250]
# [250]
# [27]
# [205]
# [190]
# [229]
# [31]
# []
# [233]
# [27]
# [252]
# [240]
# [236]
# [31]
# []
# [233]
# [236]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [268]
# []
# []
# [44]
# []
# []
# [107]
# [107]
# [27, 178]
# [63, 97]
# []
# []
# [260]
# []
# []
# []
# []
# [214]
# []
# []
# []
# []
# []
# [260]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [31]
# [279]
# []
# []
# [31]
# []
# []
# []
# []
# []
# [72]
# [37]
# [198]
# []
# []
# []
# []
# []
# [44]
# [233, 46]
# []
# []
# []
# [36]
# []
# []
# []
# []
# []
# []
# []
# []
# [27]
# [34]
# [269]
# []
# [207]
# []
# [269]
# [260]
# []
# [214]
# []
# []
# []
# [36]
# [279]
# []
# []
# []
# []
# []
# [16]
# [31]
# []
# [214]
# []
# []
# []
# []
# [229]
# [236]
# [63]
# []
# []
# [214]
# []
# [278]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [257]
# []
# [260]
# []
# [31]
# []
# []
# []
# []
# []
# []
# [205]
# [231]
# [34]
# [44]

# %%
launches_raw["launches"][1000]
# Out:
# {'id': 300,
#  'name': 'Antares 120 | Cygnus CRS Orb-2',
#  'windowstart': 'July 13, 2014 16:52:14 UTC',
#  'windowend': 'July 13, 2014 16:52:14 UTC',
#  'net': 'July 13, 2014 16:52:14 UTC',
#  'wsstamp': 1405270334,
#  'westamp': 1405270334,
#  'netstamp': 1405270334,
#  'isostart': '20140713T165214Z',
#  'isoend': '20140713T165214Z',
#  'isonet': '20140713T165214Z',
#  'status': 3,
#  'inhold': 0,
#  'tbdtime': 0,
#  'vidURLs': ['https://www.youtube.com/watch?v=KA3RhUsbf20'],
#  'vidURL': 'https://www.youtube.com/watch?v=KA3RhUsbf20',
#  'infoURLs': [],
#  'infoURL': None,
#  'holdreason': None,
#  'failreason': None,
#  'tbddate': 0,
#  'probability': -1,
#  'hashtag': None,
#  'changed': '2017-02-21 00:00:00',
#  'location': {'pads': [{'id': 109,
#     'name': 'Launch Area 0 A, Wallops Island, Virginia',
#     'infoURL': '',
#     'wikiURL': '',
#     'mapURL': 'http://maps.google.com/maps?q=37.8337+N,+75.4881+W',
#     'latitude': 37.8337,
#     'longitude': -75.4881,
#     'agencies': [{'id': 44,
#       'name': 'National Aeronautics and Space Administration',
#       'abbrev': 'NASA',
#       'countryCode': 'USA',
#       'type': 1,
#       'infoURL': None,
#       'wikiURL': 'http://en.wikipedia.org/wiki/National_Aeronautics_and_Space_Administration',
#       'changed': '2017-02-21 00:00:00',
#       'infoURLs': ['http://www.nasa.gov',
#        'https://www.youtube.com/channel/UCLA_DiR1FfKNvjuUpBHmylQ',
#        'https://twitter.com/nasa',
#        'https://www.facebook.com/nasa']}]}],
#   'id': 19,
#   'name': 'Wallops Island, Virginia, USA',
#   'infoURL': '',
#   'wikiURL': '',
#   'countryCode': 'USA'},
#  'rocket': {'id': 74,
#   'name': 'Antares 120',
#   'configuration': '120',
#   'familyname': 'Antares',
#   'agencies': [{'id': 179,
#     'name': 'Orbital ATK',
#     'abbrev': 'OA',
#     'countryCode': 'USA',
#     'type': 3,
#     'infoURL': None,
#     'wikiURL': 'https://en.wikipedia.org/wiki/Orbital_ATK',
#     'changed': '2017-02-21 00:00:00',
#     'infoURLs': ['https://www.orbitalatk.com/',
#      'https://www.youtube.com/channel/UCLr1shBflPt0esLOrNFqAPA',
#      'https://twitter.com/OrbitalATK',
#      'https://www.facebook.com/OrbitalATK']}],
#   'wikiURL': 'https://en.wikipedia.org/wiki/Antares_(rocket)',
#   'infoURLs': [],
#   'imageURL': 'https://launchlibrary1.nyc3.digitaloceanspaces.com/RocketImages/placeholder_1920.png',
#   'imageSizes': [320,
#    480,
#    640,
#    720,
#    768,
#    800,
#    960,
#    1024,
#    1080,
#    1280,
#    1440,
#    1920]},
#  'missions': [{'id': 1179,
#    'name': 'Cygnus CRS Orb-2',
#    'description': "This is the 2nd mission under NASA's Commercial Resupply Service agreement with Orbital Sciences The unmanned Cygnus cargo vessel delivered approximately 1494kg of supplies and science experiments to the International Space Station.",
#    'type': 11,
#    'wikiURL': 'https://en.wikipedia.org/wiki/Cygnus_CRS_Orb-2',
#    'typeName': 'Resupply',
#    'agencies': [],
#    'payloads': []}],
#  'lsp': {'id': 100,
#   'name': 'Orbital Sciences Corporation',
#   'abbrev': 'OSC',
#   'countryCode': 'USA',
#   'type': 3,
#   'infoURL': None,
#   'wikiURL': 'http://en.wikipedia.org/wiki/Orbital_Sciences_Corporation',
#   'changed': '2017-02-21 00:00:00',
#   'infoURLs': ['http://www.orbital.com/',
#    'https://www.youtube.com/channel/UCLr1shBflPt0esLOrNFqAPA',
#    'https://twitter.com/OrbitalATK',
#    'https://www.facebook.com/OrbitalATK']}}
